# %%
pip install pyTelegramBotAPI
# Out:
# Requirement already satisfied: pyTelegramBotAPI in d:\games\anac\lib\site-packages (3.7.1)
# Requirement already satisfied: six in d:\games\anac\lib\site-packages (from pyTelegramBotAPI) (1.14.0)
# Requirement already satisfied: requests in d:\games\anac\lib\site-packages (from pyTelegramBotAPI) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\games\anac\lib\site-packages (from requests->pyTelegramBotAPI) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\games\anac\lib\site-packages (from requests->pyTelegramBotAPI) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\games\anac\lib\site-packages (from requests->pyTelegramBotAPI) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\games\anac\lib\site-packages (from requests->pyTelegramBotAPI) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import telebot
import random
import os

# %%
bot = telebot.TeleBot('1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q')

# %%
DIR = 'koti'

# %%
@bot.message_handler(commands=['start'])
def hi(message):
    user = message.chat.id
    bot.send_message(user, "Пссс. Коты не нужны?", reply_markup=markup)

# %%
@bot.message_handler(commands=['Получить'])
def givecat(message):
    img = open(os.path.join(DIR, random.choice(os.listdir(DIR))))
    bot.send_photo(message.chat.id, img, 'rb')
    bot.send_message(user, "Держи кота", reply_markup=markup)

# %%
bot.polling()
# Out:
# 2020-06-14 20:27:37,020 (util.py:68 PollingThread) ERROR - TeleBot: "ConnectionError occurred, args=(MaxRetryError("SOCKSHTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q/getUpdates?offset=1&timeout=20 (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported'))"),)
# Traceback (most recent call last):
#   File "D:\games\Anac\lib\site-packages\socks.py", line 809, in connect
#     negotiate(self, dest_addr, dest_port)
#   File "D:\games\Anac\lib\site-packages\socks.py", line 444, in _negotiate_SOCKS5
#     self, CONNECT, dest_addr)
#   File "D:\games\Anac\lib\site-packages\socks.py", line 533, in _SOCKS5_request
#     raise SOCKS5Error("{:#04x}: {}".format(status, error))
# socks.SOCKS5Error: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\games\Anac\lib\site-packages\urllib3\contrib\socks.py", line 99, in _new_conn
#     **extra_kw
#   File "D:\games\Anac\lib\site-packages\socks.py", line 209, in create_connection
#     raise err
#   File "D:\games\Anac\lib\site-packages\socks.py", line 199, in create_connection
#     sock.connect((remote_host, remote_port))
#   File "D:\games\Anac\lib\site-packages\socks.py", line 47, in wrapper
#     return function(*args, **kwargs)
#   File "D:\games\Anac\lib\site-packages\socks.py", line 814, in connect
#     raise GeneralProxyError("Socket error", error)
# socks.GeneralProxyError: Socket error: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\games\Anac\lib\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "D:\games\Anac\lib\site-packages\urllib3\connectionpool.py", line 376, in _make_request
#     self._validate_conn(conn)
#   File "D:\games\Anac\lib\site-packages\urllib3\connectionpool.py", line 994, in _validate_conn
#     conn.connect()
#   File "D:\games\Anac\lib\site-packages\urllib3\connection.py", line 300, in connect
#     conn = self._new_conn()
#   File "D:\games\Anac\lib\site-packages\urllib3\contrib\socks.py", line 122, in _new_conn
#     self, "Failed to establish a new connection: %s" % error
# urllib3.exceptions.NewConnectionError: <urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\games\Anac\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "D:\games\Anac\lib\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "D:\games\Anac\lib\site-packages\urllib3\util\retry.py", line 436, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: SOCKSHTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q/getUpdates?offset=1&timeout=20 (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\games\Anac\lib\site-packages\telebot\util.py", line 62, in run
#     task(*args, **kwargs)
#   File "D:\games\Anac\lib\site-packages\telebot\__init__.py", line 281, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "D:\games\Anac\lib\site-packages\telebot\__init__.py", line 251, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "D:\games\Anac\lib\site-packages\telebot\apihelper.py", line 199, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "D:\games\Anac\lib\site-packages\telebot\apihelper.py", line 63, in _make_request
#     timeout=(connect_timeout, read_timeout), proxies=proxy)
#   File "D:\games\Anac\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\games\Anac\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\games\Anac\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: SOCKSHTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q/getUpdates?offset=1&timeout=20 (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported'))
# "
# ---------------------------------------------------------------------------
# SOCKS5Error                               Traceback (most recent call last)
# D:\games\Anac\lib\site-packages\socks.py in connect(self, dest_pair, catch_errors)
#     808                 negotiate = self._proxy_negotiators[proxy_type]
# --> 809                 negotiate(self, dest_addr, dest_port)
#     810             except socket.error as error:
#
# D:\games\Anac\lib\site-packages\socks.py in _negotiate_SOCKS5(self, *dest_addr)
#     443         self.proxy_peername, self.proxy_sockname = self._SOCKS5_request(
# --> 444             self, CONNECT, dest_addr)
#     445
#
# D:\games\Anac\lib\site-packages\socks.py in _SOCKS5_request(self, conn, cmd, dst)
#     532                 error = SOCKS5_ERRORS.get(status, "Unknown error")
# --> 533                 raise SOCKS5Error("{:#04x}: {}".format(status, error))
#     534
#
# SOCKS5Error: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# GeneralProxyError                         Traceback (most recent call last)
# D:\games\Anac\lib\site-packages\urllib3\contrib\socks.py in _new_conn(self)
#      98                 timeout=self.timeout,
# ---> 99                 **extra_kw
#     100             )
#
# D:\games\Anac\lib\site-packages\socks.py in create_connection(dest_pair, timeout, source_address, proxy_type, proxy_addr, proxy_port, proxy_rdns, proxy_username, proxy_password, socket_options)
#     208     if err:
# --> 209         raise err
#     210
#
# D:\games\Anac\lib\site-packages\socks.py in create_connection(dest_pair, timeout, source_address, proxy_type, proxy_addr, proxy_port, proxy_rdns, proxy_username, proxy_password, socket_options)
#     198
# --> 199             sock.connect((remote_host, remote_port))
#     200             return sock
#
# D:\games\Anac\lib\site-packages\socks.py in wrapper(*args, **kwargs)
#      46                 self.setblocking(True)
# ---> 47             return function(*args, **kwargs)
#      48         except Exception as e:
#
# D:\games\Anac\lib\site-packages\socks.py in connect(self, dest_pair, catch_errors)
#     813                     self.close()
# --> 814                     raise GeneralProxyError("Socket error", error)
#     815                 else:
#
# GeneralProxyError: Socket error: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\games\Anac\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# D:\games\Anac\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# D:\games\Anac\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# D:\games\Anac\lib\site-packages\urllib3\connection.py in connect(self)
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#
# D:\games\Anac\lib\site-packages\urllib3\contrib\socks.py in _new_conn(self)
#     121                     raise NewConnectionError(
# --> 122                         self, "Failed to establish a new connection: %s" % error
#     123                     )
#
# NewConnectionError: <urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\games\Anac\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# D:\games\Anac\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# D:\games\Anac\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: SOCKSHTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q/getUpdates?offset=1&timeout=20 (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-170-f1e0120bb9d2> in <module>
# ----> 1 bot.polling()
#
# D:\games\Anac\lib\site-packages\telebot\__init__.py in polling(self, none_stop, interval, timeout)
#     413         """
#     414         if self.threaded:
# --> 415             self.__threaded_polling(none_stop, interval, timeout)
#     416         else:
#     417             self.__non_threaded_polling(none_stop, interval, timeout)
#
# D:\games\Anac\lib\site-packages\telebot\__init__.py in __threaded_polling(self, none_stop, interval, timeout)
#     436                 or_event.wait()  # wait for polling thread finish, polling thread error or thread pool error
#     437
# --> 438                 polling_thread.raise_exceptions()
#     439                 self.worker_pool.raise_exceptions()
#     440
#
# D:\games\Anac\lib\site-packages\telebot\util.py in raise_exceptions(self)
#      79         def raise_exceptions(self):
#      80             if self.exception_event.is_set():
# ---> 81                 six.reraise(self.exc_info[0], self.exc_info[1], self.exc_info[2])
#      82
#      83         def clear_exceptions(self):
#
# D:\games\Anac\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# D:\games\Anac\lib\site-packages\telebot\util.py in run(self)
#      60                     self.received_task_event.set()
#      61
# ---> 62                     task(*args, **kwargs)
#      63                     logger.debug("Task complete")
#      64                     self.done_event.set()
#
# D:\games\Anac\lib\site-packages\telebot\__init__.py in __retrieve_updates(self, timeout)
#     279             logger.debug('Skipped {0} pending messages'.format(self.__skip_updates()))
#     280             self.skip_pending = False
# --> 281         updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#     282         self.process_new_updates(updates)
#     283
#
# D:\games\Anac\lib\site-packages\telebot\__init__.py in get_updates(self, offset, limit, timeout, allowed_updates)
#     249         :return: array of Updates
#     250         """
# --> 251         json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#     252         ret = []
#     253         for ju in json_updates:
#
# D:\games\Anac\lib\site-packages\telebot\apihelper.py in get_updates(token, offset, limit, timeout, allowed_updates)
#     197     if allowed_updates:
#     198         payload['allowed_updates'] = json.dumps(allowed_updates)
# --> 199     return _make_request(token, method_url, params=payload)
#     200
#     201
#
# D:\games\Anac\lib\site-packages\telebot\apihelper.py in _make_request(token, method_name, method, params, files)
#      61         if 'connect-timeout' in params: connect_timeout = params['connect-timeout'] + 10
#      62     result = _get_req_session().request(method, request_url, params=params, files=files,
# ---> 63                                         timeout=(connect_timeout, read_timeout), proxies=proxy)
#      64     logger.debug("The server returned: '{0}'".format(result.text.encode('utf8')))
#      65     return _check_result(method_name, result)['result']
#
# D:\games\Anac\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\games\Anac\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\games\Anac\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: SOCKSHTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot1196454753:AAETJxtf1Liq7T8pEzr2vmwUxVhMQgITD5Q/getUpdates?offset=1&timeout=20 (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x0000021DFB35F508>: Failed to establish a new connection: 0x08: Address type not supported'))
